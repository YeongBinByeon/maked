# %%
import pyautogui as pag
import mss, cv2
import numpy as np

# %%
while True:
    x, y, = pag.position()
    position_str = 'X: ' + str(x) + ' Y: ' + str(y)
    print(position_str, end='\r')

# %%
#클릭후 대기시간
pag.PAUSE = 0.03

#icon position
left_icon_pos = {'left':111, 'top':610, 'width':80, 'height':80}
right_icon_pos = {'left':283, 'top':610, 'width':80, 'height':80}

#button_position
left_button=[120,610]
right_button=[290,610]

while True:
    with mss.mss() as sct:
        left_img = np.array(sct.grab(left_icon_pos))[:,:,:3]
        right_img = np.array(sct.grab(right_icon_pos))[:,:,:3]

#         #윈도우에 이미지 띄우기
#         cv2.imshow('left_img', left_img)
#         cv2.imshow('right_img', right_img)
#         #띄우고 대기하기
#         cv2.waitKey(0)
        left_icon = compute_icon_type(left_img)
        right_icon = compute_icon_type(right_img)
        
        #print(left_icon)
        #print(right_icon)

        if left_icon == 'SWORD' and (right_icon == 'BOMB' or right_icon == 'POISON'):
            print('TAP LEFT!')
            click(left_button)
        elif right_icon == 'SWORD' and (left_icon == 'BOMB' or left_icon == 'POISON'):
            print('TAP RIGHT')
            click(right_button)
        elif left_icon == 'JEWEL' and right_icon == 'JEWEL':
            print('FEVER!')
            click(left_button)
            click(right_button)
        else:
            print('FAIL')

def compute_icon_type(img):
    mean = np.mean(img, axis=(0,1))
    result = 'gjgi'
    
    if mean[0] > 50 and mean[0] < 55 and mean[1] > 50 and mean[1] < 55 and mean[2] > 50 and mean[2] < 55:
        result = 'BOMB'
    elif mean[0] > 250 and mean[1] > 85 and mean[1] < 110 and mean[2] > 250:
        result = 'SWORD'
    elif mean[0] > 100 and mean[0] < 130 and mean[1] > 150 and mean[1] < 200 and mean[2] > 90 and mean[2] < 110:
        result = 'POISON'
    elif mean[0] > 210 and mean[0] < 230 and mean[1] > 200 and mean[1] < 225 and mean[2] > 120 and mean[2] < 135:
        result = 'JEWEL'
    return result
# Out:
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FEVER!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# TAP RIGHT
# TAP RIGHT
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP LEFT!
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# TAP RIGHT
# TAP RIGHT
# TAP RIGHT
# TAP RIGHT
# TAP RIGHT
# TAP RIGHT
# TAP RIGHT
# TAP RIGHT
# TAP RIGHT
# TAP RIGHT
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-ec20d07841d5> in <module>
#      12 while True:
#      13     with mss.mss() as sct:
# ---> 14         left_img = np.array(sct.grab(left_icon_pos))[:,:,:3]
#      15         right_img = np.array(sct.grab(right_icon_pos))[:,:,:3]
#      16
#
# C:\ProgramData\Anaconda3\lib\site-packages\mss\windows.py in grab(self, monitor)
#     293             monitor["left"],
#     294             monitor["top"],
# --> 295             SRCCOPY | CAPTUREBLT,
#     296         )
#     297         bits = self.gdi32.GetDIBits(
#
# KeyboardInterrupt:

# %%
def compute_icon_type(img):
    mean = np.mean(img, axis=(0,1))
    result = 'gjgi'
    
    if mean[0] > 50 and mean[0] < 55 and mean[1] > 50 and mean[1] < 55 and mean[2] > 50 and mean[2] < 55:
        result = 'BOMB'
    elif mean[0] > 250 and mean[1] > 85 and mean[1] < 110 and mean[2] > 250:
        result = 'SWORD'
    elif mean[0] > 100 and mean[0] < 130 and mean[1] > 150 and mean[1] < 200 and mean[2] > 90 and mean[2] < 110:
        result = 'POISON'
    elif mean[0] > 210 and mean[0] < 230 and mean[1] > 200 and mean[1] < 225 and mean[2] > 120 and mean[2] < 135:
        result = 'JEWEL'
    return result

def click(coords):
    pag.moveTo(x=coords[0], y=coords[1], duration=0.0)
    pag.mouseDown()
    pag.mouseUp()
